# %%
matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
x = range(1, 10)

# %%
plt.plot(x, x, c="green", linestyle="", marker="x")

# %%
plt.plot(x, x, c="black", linestyle="", marker="x")

# %%
plt.plot(x, x, c="green", linestyle="--", marker="x")

# %%
import seaborn as sns

# %%
sns.set()

# %%
x = range(1, 10)
plt.plot(x,x)

# %%
from scipy import stats

# %%
x = [12, 10, 11, 13, 14, 10, 13, 13, 22]
y = [1, 4, 2, 3, 5, 2, 1, 0, 0, 1, 2]

# %%
stats.ttest_ind(x,y)
# Out:
# Ttest_indResult(statistic=9.281138146360542, pvalue=2.7794419042727725e-08)

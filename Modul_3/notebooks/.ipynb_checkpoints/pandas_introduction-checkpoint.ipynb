# %%
import pandas as pd
x = pd.Series([34, 12, 23, 45])
print(x)
x.dtype
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64
# dtype('int64')

# %%
import pandas as pd
data = {'month': ['Jan', 'Feb', 'Mar'],
        'temp': [-5, 2, 3],
         'below_zero': [True, False, False]}
df = pd.DataFrame(data)
print(df)
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False

# %% [markdown]
# #2.2 Skalenniveau und Datentypen
# #Welches Skalenniveau besitzen die Variablen im obigen Beispiel? ##nominal, metrisch, nominal
# #Sind die Variablen stetig oder diskret? ##diskret, stetig, diskret
# #Was ist der Datentyp jeder einzelnen Spalte? ##Antwort: object, int, bool

# %%
data = {'month': ['Jan', 'Feb', 'Mar','Apr'],
        'temp': [-5, 2, 3,5],
        'below_zero': [True, False, False, False],
        'year': [2020,2020,2020,2020]}
df = pd.DataFrame(data)
print(df)
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %%
new_row = {'month':'Apr', 'temp':5, 'below_zero':False}
df = df.append(new_row, ignore_index=True)
print(df)
# Out:
#   month  temp  below_zero    year
# 0   Jan    -5        True  2020.0
# 1   Feb     2       False  2020.0
# 2   Mar     3       False  2020.0
# 3   Apr     5       False  2020.0
# 4   Apr     5       False     NaN

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# 1  25 to 34 years                S7                  Sunset
# 2  45 to 54 years                P1                    Park
# 3  25 to 34 years                 X            Main Library
# 4  45 to 54 years                M2                  Marina
#
#   Circulation Active Month Circulation Active Year Notice Preference Code  \
# ...

# %%
df.to_json("../data/Library_Usage.json")

# %%
df = pd.read_csv("../data/Library_Usage.csv")
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
x = df['Total Renewals']
df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(x)
print(subset)
# Out:
# 0          0
# 1         22
# 2          0
# 3          0
# 4         11
#           ..
# 423443    13
# 423444    11
# 423445    58
# 423446     0
# 423447     0
# Name: Total Renewals, Length: 423448, dtype: int64
#         Total Renewals  Total Checkouts
# 0                    0                0
# 1                   22               31
# 2                    0                0
# 3                    0                0
# 4                   11              126
# ...                ...              ...
# 423443              13              291
# 423444              11               15
# 423445              58              208
# 423446               0               26
# 423447               0                0
#
# [423448 rows x 2 columns]

# %%
df['dummy_variable'] = 5

# %%
x = df['Total Renewals']
df['Total Renewals'] = 5
x
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 423443    5
# 423444    5
# 423445    5
# 423446    5
# 423447    5
# Name: Total Renewals, Length: 423448, dtype: int64

# %%
import numpy as np

df['is_adult'] = df['Patron Type Definition'] == 'ADULT'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)

# %% [markdown]
# # 2.5 Fallstudie Feature Engineering

# %%
df['Circulation Active Year'] = pd.to_numeric(
  df['Circulation Active Year'], errors='coerce'
)
df['Circulation Active Year']
# Out:
# 0            NaN
# 1         2016.0
# 2            NaN
# 3            NaN
# 4         2016.0
#            ...
# 423443    2015.0
# 423444    2016.0
# 423445    2016.0
# 423446    2015.0
# 423447       NaN
# Name: Circulation Active Year, Length: 423448, dtype: float64

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%B"
)
df['Circulation Active Month']
# Out:
# 0        NaT
# 1        NaT
# 2        NaT
# 3        NaT
# 4        NaT
#           ..
# 423443   NaT
# 423444   NaT
# 423445   NaT
# 423446   NaT
# 423447   NaT
# Name: Circulation Active Month, Length: 423448, dtype: datetime64[ns]

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month
df['Circulation Active Month']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 423443   NaN
# 423444   NaN
# 423445   NaN
# 423446   NaN
# 423447   NaN
# Name: Circulation Active Month, Length: 423448, dtype: float64

# %%
df['Membership Duration'] = (
    df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']

# %%
df['Membership Duration'] = df['Membership Duration'].fillna(0)
df['Membership Duration']
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               5
# 1                 0                  ADULT               31               5
# 2                 0                  ADULT                0               5
# 3                 0                  ADULT                0               5
# 4                 0                  ADULT              126               5
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# 1  25 to 34 years                S7                  Sunset
# 2  45 to 54 years                P1                    Park
# 3  25 to 34 years                 X            Main Library
# 4  45 to 54 years                M2                  Marina
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.loc[df['Total Checkouts'] > 10000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 851                    9                SPECIAL            18064
# 1963                   0                  ADULT            10521
# 3499                   0                  ADULT            12740
# 20042                  3                 SENIOR            16060
# 31315                  0                  ADULT            13784
# 39585                  0                  ADULT            11086
# 57239                  0                  ADULT            10906
# 86662                  3                 SENIOR            11748
# 117628                 0                  ADULT            11817
# 120604                 3                 SENIOR            10108
# 129341                 3                 SENIOR            12757
# 138351                 0                  ADULT            10809
# 145600                 3                 SENIOR            11871
# ...

# %%
row_filter = (df['Patron Type Definition'] == 'SENIOR') & (df['Notice Preference Definition'] == 'email')
df.loc[row_filter]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 5                      3                 SENIOR                0
# 62                     3                 SENIOR              193
# 176                    3                 SENIOR                7
# 260                    3                 SENIOR              341
# 294                    3                 SENIOR               67
# ...                  ...                    ...              ...
# 423359                 3                 SENIOR                4
# 423388                 3                 SENIOR               25
# 423403                 3                 SENIOR              458
# 423405                 3                 SENIOR              280
# 423431                 3                 SENIOR                0
#
#         Total Renewals          Age Range Home Library Code  \
# 5                    0     65 to 74 years                C2
# 62                  90     65 to 74 years                A5
# ...

# %%
filter1 = (df['Total Checkouts'] >= 20) & (df['Total Checkouts'] <= 80)
filter2 =  df['Total Checkouts'].between(20, 80)
all(filter1 == filter2)
# Out:
# True

# %% [markdown]
# #2.6 Filtern

# %%
#1 Filtere den Datensatz nach Kindern unter 10 Jahren. Wie viele Einträge erhältst Du?

# %%
children = (df['Age Range'] == '0 to 9 years').sum()
children
# Out:
# 38242

# %%
#2 Gibt es Personen mit mehr als 20000 Ausleihen

# %%
checkouts = (df['Total Checkouts'] >= 20000).sum()
checkouts
# Out:
# 3

# %%
#3 Wie viele Personen stammen aus dem Norden San Franciscos (Supervisor Districts) 1, 2 und 3)?

# %%
df['Supervisor District'].isin([1, 2, 3]).sum()
# Out:
# 70091

# %% [markdown]
# #2.9 Pandas Funktionen

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.head(100)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  0                  ADULT                0               0
# 1                  0                  ADULT               31              22
# 2                  0                  ADULT                0               0
# 3                  0                  ADULT                0               0
# 4                  0                  ADULT              126              11
# ..               ...                    ...              ...             ...
# 95                 0                  ADULT                0               0
# 96                 0                  ADULT               11               0
# 97                 0                  ADULT              160              44
# 98                 0                  ADULT               11               3
# 99                 0                  ADULT               40               0
#
# ...

# %%
df.describe(include='all')
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# count      423448.000000                 423448    423448.000000
# unique               NaN                     18              NaN
# top                  NaN                  ADULT              NaN
# freq                 NaN                 272251              NaN
# mean            1.036765                    NaN       161.982097
# std             4.188198                    NaN       453.703678
# min             0.000000                    NaN         0.000000
# 25%             0.000000                    NaN         2.000000
# 50%             0.000000                    NaN        19.000000
# 75%             1.000000                    NaN       113.000000
# max           104.000000                    NaN     35907.000000
#
#         Total Renewals       Age Range Home Library Code  \
# count    423448.000000          423233            423408
# unique             NaN              10                79
# ...

# %%
print(df.min())
print(df['Total Renewals'].min())
# Out:
# Patron Type Code                    0
# Patron Type Definition          ADULT
# Total Checkouts                     0
# Total Renewals                      0
# Home Library Definition          Anza
# Circulation Active Month        April
# Circulation Active Year          2003
# Notice Preference Code              -
# Notice Preference Definition    email
# Provided Email Address          False
# Year Patron Registered           2003
# Outside of County               False
# Supervisor District               1.0
# dtype: object
# 0
# /tmp/ipykernel_35848/2524581452.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.min())

# %%
df['Total Renewals'].sum()
df['Total Renewals'].between(100, 200).sum()
# Out:
# 21739

# %%
df.columns
df.dtypes
df.shape
# Out:
# (423448, 15)

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Patron Type Code                  int64
# Patron Type Definition           object
# Total Checkouts                   int64
# Total Renewals                    int64
# Age Range                        object
# Home Library Code                object
# Home Library Definition          object
# Circulation Active Month         object
# Circulation Active Year          object
# Notice Preference Code           object
# Notice Preference Definition     object
# Provided Email Address             bool
# Year Patron Registered            int64
# Outside of County                  bool
# Supervisor District             float64
# dtype: object

# %%
df.shape
# Out:
# (423448, 15)

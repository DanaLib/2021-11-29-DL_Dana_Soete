# %%
openapc_url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"

# %%
import urllib.request
import pandas as pd

# %%
apc_file = "openapc.csv"

# %%
urllib.request.urlretrieve(openapc_url, apc_file)
# Out:
# ('openapc.csv', <http.client.HTTPMessage at 0x7f206d7c1df0>)

# %%
apcs = pd.read_csv(apc_file)

# %%
apcs
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#                            publisher                  journal_full_title  \
# ...

# %%
apcs.shape
# Out:
# (61, 17)

# %%
apcs.columns
# Out:
# Index(['institution', 'period', 'euro', 'doi', 'is_hybrid', 'publisher',
#        'journal_full_title', 'issn', 'issn_print', 'issn_electronic',
#        'license_ref', 'indexed_in_crossref', 'pmid', 'pmcid', 'ut', 'url',
#        'doaj'],
#       dtype='object')

# %%
apcs["euro"]
# Out:
# 0     2000.00
# 1     1503.12
# 2     2000.00
# 3     2000.00
# 4     1805.00
#        ...
# 56    1731.45
# 57    1600.00
# 58     219.84
# 59    1386.35
# 60    2000.00
# Name: euro, Length: 61, dtype: float64

# %%
apcs["euro"].max()
# Out:
# 2000.0

# %%
apcs["euro"].min()
# Out:
# 219.84

# %%
apcs["euro"].mean()
# Out:
# 1419.6080327868851

# %%
apcs["euro"].describe()
# Out:
# count      61.000000
# mean     1419.608033
# std       456.811349
# min       219.840000
# 25%      1178.420000
# 50%      1410.070000
# 75%      1800.000000
# max      2000.000000
# Name: euro, dtype: float64

# %%
apcs[apcs["euro"] >= 2000]
# Out:
#    institution  period    euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.0          10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.0             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.0   10.1371/journal.ppat.1005246      False
# 12   FU Berlin    2015  2000.0       10.3389/fpsyg.2015.01675      False
# 15   FU Berlin    2015  2000.0   10.1371/journal.ppat.1004781      False
# 23   FU Berlin    2015  2000.0         10.1127/metz/2015/0641      False
# 28   FU Berlin    2015  2000.0       10.3389/fnhum.2015.00551      False
# 29   FU Berlin    2015  2000.0             10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.0      10.1186/s12918-015-0183-x      False
# 45   FU Berlin    2015  2000.0   10.1371/journal.pcbi.1004200      False
# 60   FU Berlin    2015  2000.0            10.1155/2015/569512      False
#
#                            publisher               journal_full_title  \
# ...

# %%
apcs["euro"] >= 2000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Name: euro, Length: 61, dtype: bool

# %%
apcs[["euro", "publisher"]]
# Out:
#        euro                         publisher
# 0   2000.00                   Springer Nature
# 1   1503.12   American Physical Society (APS)
# 2   2000.00                   Springer Nature
# 3   2000.00  Public Library of Science (PLoS)
# 4   1805.00                   Springer Nature
# ..      ...                               ...
# 56  1731.45                   Springer Nature
# 57  1600.00                Frontiers Media SA
# 58   219.84                Frontiers Media SA
# 59  1386.35                   Springer Nature
# 60  2000.00    Hindawi Publishing Corporation
#
# [61 rows x 2 columns]

# %%
apcs["euro"].hist()
# Out:
# <AxesSubplot:>

# %%
apcs[(apcs["euro"] >= 750) & (apcs["euro"] >= 950)]
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00          10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00   10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# ...

# %%
apcs["euro"].hist(bins=20, color="pink")
# Out:
# <AxesSubplot:>

# %%
apcs[apcs["publisher"] == "Springer Nature"]
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#           publisher                  journal_full_title       issn issn_print  \
# ...

# %%
df = apcs[(apcs["publisher"] == "Springer Nature")]

# %%
df[["euro", "jounal_full_title", "euro", "doi"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20618/2563393805.py in <module>
# ----> 1 df[["euro", "jounal_full_title", "euro", "doi"]]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
df
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#           publisher                  journal_full_title       issn issn_print  \
# ...

# %%
df[["doi", "euro", "license_ref", "journal_full_title"]]
# Out:
#                              doi     euro  \
# 0          10.1038/npjqi.2015.10  2000.00
# 1      10.1103/PhysRevX.5.041008  1503.12
# 2             10.1038/ncomms9498  2000.00
# 3   10.1371/journal.ppat.1005246  2000.00
# 4      10.1186/s13099-015-0075-z  1805.00
# ..                           ...      ...
# 56     10.1186/s13015-014-0028-y  1731.45
# 57      10.3389/fpsyg.2015.00194  1600.00
# 58       10.3389/fevo.2015.00020   219.84
# 59             10.1038/srep19416  1386.35
# 60           10.1155/2015/569512  2000.00
#
#                                     license_ref  \
# 0                                           NaN
# 1   http://creativecommons.org/licenses/by/3.0/
# 2                                           NaN
# 3   http://creativecommons.org/licenses/by/4.0/
# 4                                           NaN
# ..                                          ...
# 56                                          NaN
# 57                                          NaN
# ...

# %%
apcs[(apcs["publisher"] == "Springer Nature")]
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#           publisher                  journal_full_title       issn issn_print  \
# ...

# %%
apcs[(apcs["publisher"] == "Springer Nature")][["doi", "euro", "license_ref", "journal_full_title"]]
# Out:
#                              doi     euro  \
# 0          10.1038/npjqi.2015.10  2000.00
# 1      10.1103/PhysRevX.5.041008  1503.12
# 2             10.1038/ncomms9498  2000.00
# 3   10.1371/journal.ppat.1005246  2000.00
# 4      10.1186/s13099-015-0075-z  1805.00
# ..                           ...      ...
# 56     10.1186/s13015-014-0028-y  1731.45
# 57      10.3389/fpsyg.2015.00194  1600.00
# 58       10.3389/fevo.2015.00020   219.84
# 59             10.1038/srep19416  1386.35
# 60           10.1155/2015/569512  2000.00
#
#                                     license_ref  \
# 0                                           NaN
# 1   http://creativecommons.org/licenses/by/3.0/
# 2                                           NaN
# 3   http://creativecommons.org/licenses/by/4.0/
# 4                                           NaN
# ..                                          ...
# 56                                          NaN
# 57                                          NaN
# ...

# %%
apcs[(apcs["publisher"] == "Springer Nature")
    & (apcs["euro"] >= 1000)][["doi", "euro", "license_ref", "journal_full_title"]]
# Out:
#                               doi     euro  \
# 0           10.1038/npjqi.2015.10  2000.00
# 1       10.1103/PhysRevX.5.041008  1503.12
# 2              10.1038/ncomms9498  2000.00
# 3    10.1371/journal.ppat.1005246  2000.00
# 4       10.1186/s13099-015-0075-z  1805.00
# 5    10.1371/journal.pone.0139894  1191.32
# 6    10.1371/journal.pone.0142240  1236.83
# 7        10.3389/fcimb.2015.00067  1499.08
# 8        10.5194/acp-15-6897-2015  1160.25
# 9    10.1371/journal.pone.0140050  1191.21
# 10       10.3389/fpsyg.2015.01137  1142.40
# 11       10.3389/fpsyg.2015.01661  1298.29
# 12       10.3389/fpsyg.2015.01675  2000.00
# 13              10.1038/srep11598  1165.00
# 14              10.1038/srep12681  1386.35
# 15   10.1371/journal.ppat.1004781  2000.00
# 17       10.3389/fbioe.2015.00130  1535.87
# 19   10.1371/journal.pone.0139402  1178.42
# 20       10.3389/fpsyg.2015.01267  1285.52
# 21  10.1088/1367-2630/17/8/083042  1392.30
# 22        10.3389/fevo.2015.00103  1509.22
# ...
